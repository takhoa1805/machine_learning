# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
student_depression_file_path = '../datasets/student_depression.csv'
student_depression_data = pd.read_csv(student_depression_file_path)


# Display the first few rows of the dataset
student_depression_data.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
# Display data description
student_depression_data.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# min        0.000000            0.000000          0.000000          0.000000
# 25%        6.290000            2.000000          0.000000          4.000000
# 50%        7.770000            3.000000          0.000000          8.000000
# 75%        8.920000            4.000000          0.000000         10.000000
# max       10.000000            5.000000          4.000000         12.000000
#
#          Depression
# count  27901.000000
# mean       0.585499
# std        0.492645
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
# Display data information
print(student_depression_data.info())

#Count the number of missing values in each column
missing_values = student_depression_data.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# Count NaN values in the dataset
nan_count = student_depression_data.isna().sum()
print("NaN values in the dataset:")
print(nan_count)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  object
#  11  Dietary Habits                         27901 non-null  object
#  12  Degree                                 27901 non-null  object
#  13  Have you ever had suicidal thoughts ?  27901 non-null  object
#  14  Work/Study Hours                       27901 non-null  float64
#  15  Financial Stress                       27901 non-null  object
#  16  Family History of Mental Illness       27901 non-null  object
#  17  Depression                             27901 non-null  int64
# dtypes: float64(7), int64(2), object(9)
# memory usage: 3.8+ MB
# None
# Missing values in each column:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64
# NaN values in the dataset:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %% [markdown]
# DATA DESCRIPTION
#
# Features:
# - ID: Unique identifier for each student
# - Demographics: Age, Gender, City
# - Academic Indicators: CGPA, Academic Pressure, Study Satisfaction
# - Lifestyle & Wellbeing: Sleep Duration, Dietary Habits, Work Pressure, Job Satisfaction, Work/Study Hours
# - Additional Factors: Profession, Degree, Financial Stress, Family History of Mental Illness, and whether the student has ever had suicidal thoughts
#
# Target Variable:
# - Depression_Status: A binary indicator (0/1 or Yes/No) that denotes whether a student is experiencing depression
#
#
# Data information shows that there is no Null values of every features

# %%
object_columns = student_depression_data.select_dtypes(include=['object','float64','int64']).columns
# Display unique values in object columns
for column in object_columns:
    print(f"Unique values in '{column}':")
    print(student_depression_data[column].unique())
    print()
# Out:
# Unique values in 'id':
# [     2      8     26 ... 140689 140690 140699]
#
# Unique values in 'Gender':
# ['Male' 'Female']
#
# Unique values in 'Age':
# [33. 24. 31. 28. 25. 29. 30. 27. 19. 20. 23. 18. 21. 22. 34. 32. 26. 39.
#  35. 42. 36. 58. 49. 38. 51. 44. 43. 46. 59. 54. 48. 56. 37. 41.]
#
# Unique values in 'City':
# ['Visakhapatnam' 'Bangalore' 'Srinagar' 'Varanasi' 'Jaipur' 'Pune' 'Thane'
#  'Chennai' 'Nagpur' 'Nashik' 'Vadodara' 'Kalyan' 'Rajkot' 'Ahmedabad'
#  'Kolkata' 'Mumbai' 'Lucknow' 'Indore' 'Surat' 'Ludhiana' 'Bhopal'
#  'Meerut' 'Agra' 'Ghaziabad' 'Hyderabad' 'Vasai-Virar' 'Kanpur' 'Patna'
#  'Faridabad' 'Delhi' 'Saanvi' 'M.Tech' 'Bhavna' "'Less Delhi'" 'City'
#  '3.0' "'Less than 5 Kalyan'" 'Mira' 'Harsha' 'Vaanya' 'Gaurav' 'Harsh'
#  'Reyansh' 'Kibara' 'Rashi' 'ME' 'M.Com' 'Nalyan' 'Mihir' 'Nalini'
#  'Nandini' 'Khaziabad']
#
# Unique values in 'Profession':
# ['Student' "'Civil Engineer'" 'Architect' "'UX/UI Designer'"
#  "'Digital Marketer'" "'Content Writer'" "'Educational Consultant'"
#  'Teacher' 'Manager' 'Chef' 'Doctor' 'Lawyer' 'Entrepreneur' 'Pharmacist']
#
# Unique values in 'Academic Pressure':
# [5. 2. 3. 4. 1. 0.]
#
# Unique values in 'Work Pressure':
# [0. 5. 2.]
#
# Unique values in 'CGPA':
# [ 8.97    5.9     7.03    5.59    8.13    5.7     9.54    8.04    9.79
#   8.38    6.1     7.04    8.52    5.64    8.58    6.51    7.25    7.83
#   9.93    8.74    6.73    5.57    8.59    7.1     6.08    5.74    9.86
#   6.7     6.21    5.87    6.37    9.72    5.88    9.56    6.99    5.24
#   9.21    7.85    6.95    5.86    7.92    9.66    8.94    9.71    7.87
#   5.6     7.9     5.46    6.79    8.7     7.38    8.5     7.09    9.82
#   8.89    7.94    9.11    6.75    7.53    9.49    9.01    7.64    5.27
#   6.      9.44    5.75    7.51    9.05    6.38    8.95    9.88    5.32
#   6.27    7.7     8.1     9.59    8.96    5.51    7.43    8.79    9.95
#   5.37    6.86    8.32    9.74    5.66    7.48    8.23    8.81    6.03
#   5.56    5.68    5.14    7.61    6.17    8.17    9.87    8.75    6.16
#   9.5     7.99    5.67    8.92    6.19    5.76    6.25    5.11    5.58
#   5.65    9.89    8.03    6.61    9.41    8.64    7.21    8.28    6.04
#   9.13    8.08    9.96    5.12    8.35    7.07    9.6     9.24    8.54
#   8.78    8.93    8.91    9.04    6.83    5.85    7.74    6.41    8.9
#   7.75    7.88    5.42    7.52    7.68    8.4     9.39    6.84    5.99
#   8.62    8.53    7.47    6.78    6.42    9.92    8.39    5.89    7.22
#   6.81    9.02    9.97    9.63    9.67    5.41    7.27    6.05    6.85
#   9.33    5.81    6.53    5.98    6.02    6.74    5.26    7.72    7.39
#   8.43    9.34    5.44    5.82    5.72    8.19    8.44    8.98    9.37
#   5.8     7.28    7.6     7.91    9.17    7.46    9.43    9.91    9.36
#   5.16    7.08    9.26    8.83   10.      7.8     9.46    6.63    7.24
#   6.47    7.77    5.06    7.17    8.24    6.88    9.03    5.08    5.45
#   8.46    9.19    6.36    8.73    7.11    9.12    9.4     8.11    9.98
#   5.55    8.61    8.14    6.89    9.84    5.48    8.21    7.82    8.55
#   5.79    8.77    8.29    6.92    7.37    9.7     6.26    7.26    7.5
#   6.82    7.15    5.77    5.91    5.1     7.71    9.06    5.71    5.84
#   9.42    6.23    6.29    5.25    9.69    9.9     6.39    8.09    5.83
#   5.47    6.56    8.71    9.94    6.69    5.52    7.3     7.02    6.33
#   8.07    8.37    8.      7.79    8.65    6.28    7.35    8.69    7.12
#   7.32    7.13    5.97    5.09    6.91    6.76    6.52    7.45    8.56
#   6.5     8.63    8.27    8.49    6.59    9.29    5.3     7.06    5.38
#   6.65    9.16    8.01    8.25    8.02    8.47    7.34    8.88    7.14
#   8.42    5.17    9.1     7.49    9.85    7.42    9.31    6.35    7.
#   5.39    5.61    9.78    9.25    5.69    9.47    8.16    7.23    6.46
#   0.      8.26    6.32    6.77    8.85    5.03    7.65    5.78    6.24
#   5.35    6.06    7.78    6.64    7.0625  6.98    6.44    6.09  ]
#
# Unique values in 'Study Satisfaction':
# [2. 5. 3. 4. 1. 0.]
#
# Unique values in 'Job Satisfaction':
# [0. 3. 4. 2. 1.]
#
# Unique values in 'Sleep Duration':
# ["'5-6 hours'" "'Less than 5 hours'" "'7-8 hours'" "'More than 8 hours'"
#  'Others']
#
# Unique values in 'Dietary Habits':
# ['Healthy' 'Moderate' 'Unhealthy' 'Others']
#
# Unique values in 'Degree':
# ['B.Pharm' 'BSc' 'BA' 'BCA' 'M.Tech' 'PhD' "'Class 12'" 'B.Ed' 'LLB' 'BE'
#  'M.Ed' 'MSc' 'BHM' 'M.Pharm' 'MCA' 'MA' 'B.Com' 'MD' 'MBA' 'MBBS' 'M.Com'
#  'B.Arch' 'LLM' 'B.Tech' 'BBA' 'ME' 'MHM' 'Others']
#
# Unique values in 'Have you ever had suicidal thoughts ?':
# ['Yes' 'No']
#
# Unique values in 'Work/Study Hours':
# [ 3.  9.  4.  1.  0. 12.  2. 11. 10.  6.  8.  5.  7.]
#
# Unique values in 'Financial Stress':
# ['1.0' '2.0' '5.0' '3.0' '4.0' '?']
#
# Unique values in 'Family History of Mental Illness':
# ['No' 'Yes']
#
# Unique values in 'Depression':
# [1 0]

# %% [markdown]
# DATA TRANSFORMATION
#
# After inspecting each feature of data, we can see that:
# - At 'City' feature, there are some incorrect, irrelevant values such as:
#     - '3.0'
#     - 'City'
#     - 'Less than 5 Kalyan' => Kalyan city is already mentioned
#     - 'ME' => this could be Master of Engineering in 'Profession' column
#     - 'M.Com' => this could be Master of Commerce in 'Profession' column
# - At 'Financial Stress' feature, there are some rows that contain '?' value. Which could stand for 'Null' or 'Not available'
# - We only care about Student so we can drop all rows that are not student in Profession, and then remove Profession column
# - There are ambiguous like '?' values in 'Financial Stress' column, 'Other' in 'Degree', 'Dietary Habits', 'Sleep Duration'
# - There are 3 rows that have missing values, in Financial Stress column. The amount of missing data is not significant compared to the data set, so we drop columns that contain missing, or NaN value

# %%
others_count = student_depression_data[student_depression_data['Degree'] == 'Others'].shape[0] + student_depression_data[student_depression_data['Dietary Habits'] == 'Others'].shape[0] + student_depression_data[student_depression_data['Sleep Duration'] == 'Others'].shape[0] 
print(others_count)
# Out:
# 65

# %% [markdown]
# => There are total 65 'Others' value across those columns. So we can drop all of those without causing so much bias to our data

# %%
student_depression_data = student_depression_data[student_depression_data['Degree'] != 'Others']
student_depression_data = student_depression_data[student_depression_data['Dietary Habits'] != 'Others']
student_depression_data = student_depression_data[student_depression_data['Sleep Duration'] != 'Others']

# %%
city_irrelevant_value = ['3.0', 'City',"'Less than 5 Kalyan'",'ME', 'M.Com','M.Tech', "'Less Delhi'"]
# Count number of irrelevant values in the 'City' column
city_irrelevant_count = student_depression_data['City'].isin(city_irrelevant_value).sum()
print(f"Number of irrelevant values in 'City' column: {city_irrelevant_count}")

financial_stress_irrelevant_value = ['?']
# Count number of irrelevant values in the 'Financial Stress' column
financial_stress_irrelevant_count = student_depression_data['Financial Stress'].isin(financial_stress_irrelevant_value).sum()
print(f"Number of irrelevant values in 'Financial Stress' column: {financial_stress_irrelevant_count}")


# Change Have you ever had suicidal thoughts ? to 1 and 0
student_depression_data['Have you ever had suicidal thoughts ?'] = student_depression_data['Have you ever had suicidal thoughts ?'].replace({'Yes': 1, 'No': 0})
student_depression_data['Have you ever had suicidal thoughts ?'] = pd.to_numeric(student_depression_data['Have you ever had suicidal thoughts ?'], errors='coerce')

# Change Family History of Mental Illness to 1 and 0
student_depression_data['Family History of Mental Illness'] = student_depression_data['Family History of Mental Illness'].replace({'Yes': 1, 'No': 0})
student_depression_data['Family History of Mental Illness'] = pd.to_numeric(student_depression_data['Family History of Mental Illness'], errors='coerce')

# Choose students only in Profession column
# Remove the 'Profession' column from the dataset
student_depression_data =  student_depression_data[student_depression_data['Profession'] == 'Student'].drop(columns=['Profession'])

# Remove id column
student_depression_data = student_depression_data.drop(columns=['id'])

# Change financial stress to numerica values
student_depression_data['Financial Stress'] = pd.to_numeric(student_depression_data['Financial Stress'], errors='coerce')

# Number of NaN/missing values in the dataset before
print("Number of NaN/missing values in the dataset before:")
print(student_depression_data.isna().sum())
# Drop missing value rows
student_depression_data = student_depression_data.dropna()
# Number of NaN/missing values in the dataset after
print("Number of NaN/missing values in the dataset after:")
print(student_depression_data.isna().sum())

# 

## Display the first few rows of the modified dataset
student_depression_data.head()
# Out:
# Number of irrelevant values in 'City' column: 8
# Number of irrelevant values in 'Financial Stress' column: 3
# Number of NaN/missing values in the dataset before:
# Gender                                   0
# Age                                      0
# City                                     0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64
# Number of NaN/missing values in the dataset after:
# Gender                                   0
# Age                                      0
# City                                     0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64
# /tmp/ipykernel_477528/2995258189.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   student_depression_data['Have you ever had suicidal thoughts ?'] = student_depression_data['Have you ever had suicidal thoughts ?'].replace({'Yes': 1, 'No': 0})
# /tmp/ipykernel_477528/2995258189.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   student_depression_data['Family History of Mental Illness'] = student_depression_data['Family History of Mental Illness'].replace({'Yes': 1, 'No': 0})
#    Gender   Age           City  Academic Pressure  Work Pressure  CGPA  \
# 0    Male  33.0  Visakhapatnam                5.0            0.0  8.97
# 1  Female  24.0      Bangalore                2.0            0.0  5.90
# 2    Male  31.0       Srinagar                3.0            0.0  7.03
# 3  Female  28.0       Varanasi                3.0            0.0  5.59
# 4  Female  25.0         Jaipur                4.0            0.0  8.13
#
#    Study Satisfaction  Job Satisfaction       Sleep Duration Dietary Habits  \
# 0                 2.0               0.0          '5-6 hours'        Healthy
# 1                 5.0               0.0          '5-6 hours'       Moderate
# 2                 5.0               0.0  'Less than 5 hours'        Healthy
# 3                 2.0               0.0          '7-8 hours'       Moderate
# 4                 3.0               0.0          '5-6 hours'       Moderate
#
#     Degree  Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0  B.Pharm                                      1               3.0
# 1      BSc                                      0               3.0
# 2       BA                                      0               9.0
# 3      BCA                                      1               4.0
# 4   M.Tech                                      1               1.0
#
#    Financial Stress  Family History of Mental Illness  Depression
# 0               1.0                                 0           1
# 1               2.0                                 1           0
# 2               1.0                                 1           0
# 3               5.0                                 1           1
# 4               1.0                                 0           0

# %% [markdown]
# The number of irrelevant, incorrect values in datasets of 'City' and 'Financial Stress' columns is trivial. So we are dropping those irrelevant values

# %%
# Drop irrelevant values in 'City' column
student_depression_data = student_depression_data[~student_depression_data['City'].isin(city_irrelevant_value)]
# Drop irrelevant values in 'Financial Stress' column
student_depression_data = student_depression_data[~student_depression_data['Financial Stress'].isin(financial_stress_irrelevant_value)]

# %% [markdown]
# DATA VISUALIZATION

# %%
# ---------- HISTOGRAM PLOTS ----------

def plot_histograms_in_grid(columns, is_categorical=True):
    num_columns = len(columns)
    cols_per_row = 3
    rows = math.ceil(num_columns / cols_per_row)

    fig, axs = plt.subplots(rows, cols_per_row, figsize=(cols_per_row * 6, rows * 5))
    axs = axs.flatten()

    for i, column in enumerate(columns):
        ax = axs[i]
        if is_categorical:
            student_depression_data[column].value_counts().plot(kind='bar', color='skyblue', edgecolor='black', ax=ax)
        else:
            student_depression_data[column].hist(bins=20, color='skyblue', edgecolor='black', ax=ax)
        ax.set_title(f'Histogram of {column}')
        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')
        ax.grid(axis='y', linestyle='--', alpha=0.7)
        ax.tick_params(axis='x', rotation=45)

    # Hide empty subplots if any
    for j in range(i+1, len(axs)):
        fig.delaxes(axs[j])

    plt.tight_layout()
    plt.show()

# Categorical histograms
categorical_columns = student_depression_data.select_dtypes(include=['object']).columns
plot_histograms_in_grid(categorical_columns, is_categorical=True)

# Non-categorical histograms
non_categorical_columns = student_depression_data.select_dtypes(exclude=['object']).columns
plot_histograms_in_grid(non_categorical_columns, is_categorical=False)

# ---------- SCATTER PLOTS (DEPRESSION VS OTHER FEATURES) ----------

def plot_depression_scatter_in_grid(columns):
    cols_per_row = 3
    rows = math.ceil(len(columns) / cols_per_row)

    fig, axs = plt.subplots(rows, cols_per_row, figsize=(cols_per_row * 6, rows * 5))
    axs = axs.flatten()

    for i, column in enumerate(columns):
        ax = axs[i]
        depression_count = (
            student_depression_data[student_depression_data['Depression'] == 1]
            .groupby(column)
            .size()
            .reset_index(name='Number of Depression')
        )

        # Convert x-axis values to string for consistency in categorical-like features
        depression_count[column] = depression_count[column].astype(str)

        ax.scatter(depression_count['Number of Depression'], depression_count[column], alpha=0.5, color='blue')
        ax.set_title(f'Depression Count vs {column}')
        ax.set_xlabel('Number of Depression Cases')
        ax.set_ylabel(column)
        ax.tick_params(axis='y', rotation=45)
        ax.grid(True)

    # Hide empty subplots
    for j in range(i+1, len(axs)):
        fig.delaxes(axs[j])

    plt.tight_layout()
    plt.show()

# All other features except 'Depression' and 'id'
numerical_columns = student_depression_data.select_dtypes(include=['int64', 'float64', 'object']).columns
filtered_columns = [col for col in numerical_columns if col not in ['Depression', 'id']]
plot_depression_scatter_in_grid(filtered_columns)

# %% [markdown]
# FEATURE SELECTION
#
# - By visualizing Student Depression data, we can see that:
#     - In 'Degree' column, 'Class 12' students seems to have highest depression among all degrees. However, the number of 'Class 12' student is much more that other degrees, so by using 'Degree' feature for our model, it could causes bias toward 'Class 12' student. So we remove 'Degree' feature out of the training data.
#     - In 'Job Satisfaction' column, most of the data is '0.0'. It also causes bias toward people who is 'Unsatisfied with the job'. So we remove 'Job Satisfaction' feature out of the training data
#     - The same with 'Work Pressure' as 'Job Satisfaction'

# %%
preprocessed_student_depression_data = student_depression_data.drop(columns=['Degree','Job Satisfaction','Work Pressure'])

# %% [markdown]
# APPLY ONE HOT ENCODING METHOD
# - Our data currently is a mixture of numerical values and categorical values. To make our data consistent, we convert every catergorical values into numerical values using one-hot encoding
# - Features that needed we apply one-hot encoding method is:
#     - Gender
#     - City
#     - Sleep duraction
#     - Dietary habits

# %%
from sklearn.preprocessing import OneHotEncoder


# One-hot encode categorical columns
categorical_columns = preprocessed_student_depression_data.select_dtypes(include=['object']).columns
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')  # Use drop='first' to avoid dummy variable trap
encoded_features = encoder.fit_transform(preprocessed_student_depression_data[categorical_columns])
encoded_feature_names = encoder.get_feature_names_out(categorical_columns)


encoded_df = pd.DataFrame(encoded_features, columns=encoded_feature_names)
# Concatenate the encoded features with the original DataFrame
preprocessed_student_depression_data = pd.concat([preprocessed_student_depression_data.drop(columns=categorical_columns), encoded_df], axis=1)




# Count NaN value of every column
nan_counts = preprocessed_student_depression_data.isna().sum()
nan_rows = preprocessed_student_depression_data[preprocessed_student_depression_data.isna().any(axis=1)]

print("Counts of NaN values for each column:")
print(nan_counts[nan_counts > 0])

preprocessed_student_depression_data = preprocessed_student_depression_data.dropna()

## Display the first few rows of the preprocessed dataset
# preprocessed_student_depression_data.head()

print("Number of missing values in each column after preprocessing:")
print(preprocessed_student_depression_data.isna().sum())

# preprocessed_student_depression_data.info()

# Save the preprocessed data to a new CSV file
preprocessed_student_depression_file_path = '../datasets/preprocessed_student_depression.csv'
preprocessed_student_depression_data.to_csv(preprocessed_student_depression_file_path, index=False)
print(f"Preprocessed data saved to {preprocessed_student_depression_file_path}")
# Out:
# Counts of NaN values for each column:
# Age                                      106
# Academic Pressure                        106
# CGPA                                     106
# Study Satisfaction                       106
# Have you ever had suicidal thoughts ?    106
#                                         ...
# Sleep Duration_'Less than 5 hours'       106
# Sleep Duration_'More than 8 hours'       106
# Dietary Habits_Healthy                   106
# Dietary Habits_Moderate                  106
# Dietary Habits_Unhealthy                 106
# Length: 63, dtype: int64
# Number of missing values in each column after preprocessing:
# Age                                      0
# Academic Pressure                        0
# CGPA                                     0
# Study Satisfaction                       0
# Have you ever had suicidal thoughts ?    0
#                                         ..
# Sleep Duration_'Less than 5 hours'       0
# Sleep Duration_'More than 8 hours'       0
# Dietary Habits_Healthy                   0
# Dietary Habits_Moderate                  0
# Dietary Habits_Unhealthy                 0
# Length: 63, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 27688 entries, 0 to 27793
# Data columns (total 63 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Age                                    27688 non-null  float64
#  1   Academic Pressure                      27688 non-null  float64
#  2   CGPA                                   27688 non-null  float64
#  3   Study Satisfaction                     27688 non-null  float64
#  4   Have you ever had suicidal thoughts ?  27688 non-null  float64
#  5   Work/Study Hours                       27688 non-null  float64
#  6   Financial Stress                       27688 non-null  float64
#  7   Family History of Mental Illness       27688 non-null  float64
#  8   Depression                             27688 non-null  float64
#  9   Gender_Female                          27688 non-null  float64
#  10  Gender_Male                            27688 non-null  float64
#  11  City_Agra                              27688 non-null  float64
#  12  City_Ahmedabad                         27688 non-null  float64
#  13  City_Bangalore                         27688 non-null  float64
#  14  City_Bhavna                            27688 non-null  float64
#  15  City_Bhopal                            27688 non-null  float64
#  16  City_Chennai                           27688 non-null  float64
#  17  City_Delhi                             27688 non-null  float64
#  18  City_Faridabad                         27688 non-null  float64
#  19  City_Gaurav                            27688 non-null  float64
#  20  City_Ghaziabad                         27688 non-null  float64
#  21  City_Harsh                             27688 non-null  float64
#  22  City_Harsha                            27688 non-null  float64
#  23  City_Hyderabad                         27688 non-null  float64
#  24  City_Indore                            27688 non-null  float64
#  25  City_Jaipur                            27688 non-null  float64
#  26  City_Kalyan                            27688 non-null  float64
#  27  City_Kanpur                            27688 non-null  float64
#  28  City_Khaziabad                         27688 non-null  float64
#  29  City_Kibara                            27688 non-null  float64
#  30  City_Kolkata                           27688 non-null  float64
#  31  City_Lucknow                           27688 non-null  float64
#  32  City_Ludhiana                          27688 non-null  float64
#  33  City_Meerut                            27688 non-null  float64
#  34  City_Mihir                             27688 non-null  float64
#  35  City_Mira                              27688 non-null  float64
#  36  City_Mumbai                            27688 non-null  float64
#  37  City_Nagpur                            27688 non-null  float64
#  38  City_Nalini                            27688 non-null  float64
#  39  City_Nalyan                            27688 non-null  float64
#  40  City_Nandini                           27688 non-null  float64
#  41  City_Nashik                            27688 non-null  float64
#  42  City_Patna                             27688 non-null  float64
#  43  City_Pune                              27688 non-null  float64
#  44  City_Rajkot                            27688 non-null  float64
#  45  City_Rashi                             27688 non-null  float64
#  46  City_Reyansh                           27688 non-null  float64
#  47  City_Saanvi                            27688 non-null  float64
#  48  City_Srinagar                          27688 non-null  float64
#  49  City_Surat                             27688 non-null  float64
#  50  City_Thane                             27688 non-null  float64
#  51  City_Vaanya                            27688 non-null  float64
#  52  City_Vadodara                          27688 non-null  float64
#  53  City_Varanasi                          27688 non-null  float64
#  54  City_Vasai-Virar                       27688 non-null  float64
#  55  City_Visakhapatnam                     27688 non-null  float64
#  56  Sleep Duration_'5-6 hours'             27688 non-null  float64
#  57  Sleep Duration_'7-8 hours'             27688 non-null  float64
#  58  Sleep Duration_'Less than 5 hours'     27688 non-null  float64
#  59  Sleep Duration_'More than 8 hours'     27688 non-null  float64
#  60  Dietary Habits_Healthy                 27688 non-null  float64
#  61  Dietary Habits_Moderate                27688 non-null  float64
#  62  Dietary Habits_Unhealthy               27688 non-null  float64
# dtypes: float64(63)
# memory usage: 13.5 MB
# Preprocessed data saved to ../datasets/preprocessed_student_depression.csv
